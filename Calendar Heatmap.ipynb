# %%
import pandas as pd

# %%
dates = pd.read_csv("data/calheat.csv")

# %%
dates["Value"]=dates["Low"]

# %%
dates.sort("Date")[["Date","Value"]].to_csv("data/calheat.csv")
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %%
dates
# Out:
#          i        Date     Value
# 0        0  1990-01-02   2732.51
# 1        1  1990-01-03   2786.26
# 2        2  1990-01-04   2766.42
# 3        3  1990-01-05   2758.11
# 4        4  1990-01-08   2753.41
# 5        5  1990-01-09   2760.03
# 6        6  1990-01-10   2725.47
# 7        7  1990-01-11   2748.29
# 8        8  1990-01-12   2675.98
# 9        9  1990-01-15   2656.36
# 10      10  1990-01-16   2634.17
# 11      11  1990-01-17   2643.77
# 12      12  1990-01-18   2625.85
# 13      13  1990-01-19   2657.85
# 14      14  1990-01-22   2595.27
# 15      15  1990-01-23   2584.01
# 16      16  1990-01-24   2534.23
# 17      17  1990-01-25   2546.17
# 18      18  1990-01-26   2516.89
# 19      19  1990-01-29   2522.97
# 20      20  1990-01-30   2513.06
# 21      21  1990-01-31   2546.85
# 22      22  1990-02-01   2571.85
# 23      23  1990-02-02   2577.03
# 24      24  1990-02-05   2592.12
# 25      25  1990-02-06   2588.29
# 26      26  1990-02-07   2579.28
# ...
